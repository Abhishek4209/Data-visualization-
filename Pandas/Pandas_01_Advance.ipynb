# %%
import pandas as pd

# %%
df=pd.read_csv("Raw_Housing_Prices.csv")
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
df.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %% [markdown]
# # **Describe:-**

# %% [markdown]
# # **describe function is always work on numerical data not on categoriical data set**

# %%
df.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
df[["Date House was Sold","Waterfront View","No of Times Visited","Condition of the House"]]
# Out:
#       Date House was Sold Waterfront View No of Times Visited  \
# 0         14 October 2017              No                 NaN
# 1        14 December 2017              No                 NaN
# 2        15 February 2016              No                 NaN
# 3        14 December 2017              No                 NaN
# 4        15 February 2016              No                 NaN
# ...                   ...             ...                 ...
# 21608         14 May 2017              No                 NaN
# 21609    15 February 2016              No                 NaN
# 21610        14 June 2017              No                 NaN
# 21611     15 January 2016              No                 NaN
# 21612     14 October 2017              No                 NaN
#
#       Condition of the House
# 0                       Fair
# 1                       Fair
# 2                       Fair
# 3                  Excellent
# 4                       Fair
# ...                      ...
# ...

# %% [markdown]
# # **Sepration of Data frame with data types:-**

# %%
df.dtypes=="object"
# Out:
# ID                                           False
# Date House was Sold                           True
# Sale Price                                   False
# No of Bedrooms                               False
# No of Bathrooms                              False
# Flat Area (in Sqft)                          False
# Lot Area (in Sqft)                           False
# No of Floors                                 False
# Waterfront View                               True
# No of Times Visited                           True
# Condition of the House                        True
# Overall Grade                                False
# Area of the House from Basement (in Sqft)    False
# Basement Area (in Sqft)                      False
# Age of House (in Years)                      False
# Renovated Year                               False
# Zipcode                                      False
# Latitude                                     False
# ...

# %% [markdown]
# # **Categorical Data:-**

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Date House was Sold', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House'],
#       dtype='object')

# %%
type(df.dtypes[df.dtypes=="object"])
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes=="object"].index].describe()
# Out:
#        Date House was Sold Waterfront View No of Times Visited  \
# count                21613           21613                2124
# unique                  13               2                   4
# top          15 April 2016              No               Twice
# freq                  2231           21450                 963
#
#        Condition of the House
# count                   21613
# unique                      5
# top                      Fair
# freq                    14031

# %% [markdown]
# # **For Float Data Type :-**

# %%
df[df.dtypes[df.dtypes=="float"].index]
# Out:
#        Sale Price  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0        221900.0             1.00               1180.0              5650.0
# 1        538000.0             2.25               2570.0              7242.0
# 2        180000.0             1.00                770.0             10000.0
# 3        604000.0             3.00               1960.0              5000.0
# 4        510000.0             2.00               1680.0              8080.0
# ...           ...              ...                  ...                 ...
# 21608    360000.0             2.50               1530.0              1131.0
# 21609    400000.0             2.50               2310.0              5813.0
# 21610    402101.0             0.75               1020.0              1350.0
# 21611    400000.0             2.50               1600.0              2388.0
# 21612    325000.0             0.75               1020.0              1076.0
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date House was Sold', 'Sale Price', 'No of Bedrooms',
#        'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
#        'No of Floors', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House', 'Overall Grade',
#        'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude',
#        'Longitude', 'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
df[["No of Bedrooms"]][4:10:2]
# Out:
#    No of Bedrooms
# 4               3
# 6               3
# 8               3

# %% [markdown]
# # **Create a new collum in our data frame:-**

# %%
df["new_collum"]=0
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                 NaN  ...
# 1              No                 NaN  ...
# ...

# %%
df["Total_Rooms"]=df["No of Bedrooms"]+df["No of Bathrooms"]
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Basement Area (in Sqft)  \
# 0              No                 NaN  ...                       0
# ...

# %% [markdown]
# # **Categorical:-**

# %%
pd.Categorical(df["No of Floors"])
# Out:
# [1.0, 2.0, 1.0, 1.0, 1.0, ..., 3.0, 2.0, 2.0, 2.0, 2.0]
# Length: 21613
# Categories (6, float64): [1.0, 1.5, 2.0, 2.5, 3.0, 3.5]

# %%
df["Sale Price"].unique()
# Out:
# array([221900., 538000., 180000., ..., 541800., 610685., 402101.])

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Basement Area (in Sqft)  \
# 0              No                 NaN  ...                       0
# ...

# %% [markdown]
# # **Filter operation in Data set:-**

# %%
df[df["Sale Price"]>2500000]
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 269    7960900060         15 May 2016   2900000.0               4
# 300    3225069065        14 June 2017   3080000.0               4
# 656    3760500116    14 November 2017   3070000.0               3
# 1164   1247600105     14 October 2017   5110000.0               5
# 1315   7558700030       15 April 2016   5300000.0               6
# ...           ...                 ...         ...             ...
# 20460  9808100150       15 April 2016   3350000.0               5
# 20535  1370800515     14 October 2017   2950000.0               4
# 21040  6447300365    14 November 2017   2900000.0               5
# 21530  8964800330       15 April 2016   3000000.0               4
# 21576  9253900271     15 January 2016   3570000.0               5
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 269               3.25               5050.0             20100.0           1.5
# ...

# %%
df[df["Total_Rooms"]>6]
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 3      2487200875    14 December 2017    604000.0               4
# 5      7237550310         14 May 2017   1230000.0               4
# 14     1175000570       15 March 2016    530000.0               5
# 15     9297300055     15 January 2016    650000.0               4
# 22     7137970340        14 July 2017    285000.0               5
# ...           ...                 ...         ...             ...
# 21599  7202300110   14 September 2017    810000.0               4
# 21600   249000205     14 October 2017   1540000.0               5
# 21605  3448900210     14 October 2017    610685.0               4
# 21606  7936000429       15 March 2016   1010000.0               4
# 21609  6600060120    15 February 2016    400000.0               4
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 3                 3.00               1960.0              5000.0           1.0
# ...

# %%
df[(df["Total_Rooms"]>6) & (df["Sale Price"]>2500000)]
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 269    7960900060         15 May 2016   2900000.0               4
# 300    3225069065        14 June 2017   3080000.0               4
# 1164   1247600105     14 October 2017   5110000.0               5
# 1315   7558700030       15 April 2016   5300000.0               6
# 1433   9471200370       15 March 2016   2540000.0               4
# ...           ...                 ...         ...             ...
# 20460  9808100150       15 April 2016   3350000.0               5
# 20535  1370800515     14 October 2017   2950000.0               4
# 21040  6447300365    14 November 2017   2900000.0               5
# 21530  8964800330       15 April 2016   3000000.0               4
# 21576  9253900271     15 January 2016   3570000.0               5
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 269               3.25               5050.0             20100.0           1.5
# ...

# %%
df[0:2]
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
#
#   Waterfront View No of Times Visited  ... Basement Area (in Sqft)  \
# 0              No                 NaN  ...                       0
# 1              No                 NaN  ...                     400
#
#    Age of House (in Years)  Renovated Year  Zipcode  Latitude  Longitude  \
# 0                       63               0  98178.0   47.5112   -122.257
# 1                       67            1991  98125.0   47.7210   -122.319
#
#    Living Area after Renovation (in Sqft)  \
# 0                                  1340.0
# ...

# %% [markdown]
# # **Loc:-**

# %%
df.loc[0:2,["Sale Price","No of Bathrooms"]]
# Out:
#    Sale Price  No of Bathrooms
# 0    221900.0             1.00
# 1    538000.0             2.25
# 2    180000.0             1.00

# %% [markdown]
# # **Iloc:-**

# %% [markdown]
# ### **It takes the index number of columns**

# %%
df.iloc[0:2,[3,1,2]]
# Out:
#    No of Bedrooms Date House was Sold  Sale Price
# 0               3     14 October 2017    221900.0
# 1               3    14 December 2017    538000.0

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df["No of Times Visited"].isnull().sum()
# Out:
# 19489

# %%
mode_no_of_time_visits=df[df["No of Times Visited"].notna()]["No of Times Visited"].mode()[0]

# %%
df["mode_no_of_time_visits"]=df["No of Times Visited"].fillna(mode_no_of_time_visits)
sns.heatmap(df.isnull())
# Out:
# <Axes: >
